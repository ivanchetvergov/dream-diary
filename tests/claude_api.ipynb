# %% [markdown]
# # Test Claude API for DreamWeaver AI
#
# Test the Anthropic Claude integration.

# %%
# !pip install langchain-anthropic python-dotenv

# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("ANTHROPIC_API_KEY")
if not api_key:
    print("Set ANTHROPIC_API_KEY in .env")
# Out:
# /Users/ivan/myvenv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
import sys
sys.path.append('..')

from agent.dream_agent import DreamDiaryAgent

agent = DreamDiaryAgent()
test_dream = (
    "I dreamed I was flying over a city, "
    "feeling free but then fell into water."
)
response = agent.process_dream(test_dream)
print("Agent Response:", response)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 import sys
#       2 sys.path.append('..')
# ----> 4 from agent.dream_agent import DreamAgent
#       6 agent = DreamAgent()
#       7 test_dream = (
#       8     "I dreamed I was flying over a city, "
#       9     "feeling free but then fell into water."
#      10 )
#
# ImportError: cannot import name 'DreamAgent' from 'agent.dream_agent' (/Users/ivan/pat projects/dream-diary/tests/../agent/dream_agent.py)
